# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
lhs72 = pd.read_csv('Data/OBSERVED/Processed/norm_RVcorr_LHS72.txt',names=['wave','flux'],delim_whitespace=True)

# %%
synth = pd.read_csv('Parameter_Estimation/Results/LHS72/conv1.34_norm_lte40.5-4.88-1.3a+X.X.BT-Settl.CIFIST2011_2017.spec.7.txt',names=['wave','flux'],delim_whitespace=True)

# %%
plt.figure(figsize=(15,10))
plt.plot(lhs72.wave,lhs72.flux,lw=1)
plt.plot(synth.wave,synth.flux,lw=1)
plt.xlim(8400,9000)
plt.legend()
plt.savefig('red_arm.png',dpi=500,facecolor='white')
# Out:
# No handles with labels found to put in legend.
