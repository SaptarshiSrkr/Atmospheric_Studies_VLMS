# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from interpolation_abun import abun_interpolate

# %%
# %matplotlib notebook

# %%
gaprange = [8200,8390]
telluric_ranges = [[6860, 6960],[7550, 7650],[8200, 8430]]

# %%
plt.figure(figsize=(15,10))

for abun in np.arange(4.35,5.25,0.2):
    df = abun_interpolate(4.7,'Ti',abun,gaprange,telluric_ranges)
    plt.plot(df['wave'],df['flux'],label=f'{abun}')
    
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1500.16">
