# %%
from interpolation_abun import abun_interpolate

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.plot(abun_interpolate(4.7,'Ca',6.0)['wave'],abun_interpolate(4.7,'Ca',6.0)['flux'],label='6.0')
plt.plot(abun_interpolate(4.7,'Ca',6.1)['wave'],abun_interpolate(4.7,'Ca',6.1)['flux'],label='6.1')
plt.plot(abun_interpolate(4.7,'Ca',6.2)['wave'],abun_interpolate(4.7,'Ca',6.2)['flux'],label='6.2')

plt.xlim(8530,8550)
plt.legend()
